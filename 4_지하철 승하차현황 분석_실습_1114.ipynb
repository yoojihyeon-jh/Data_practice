# %% [markdown]
# * 데이터 수집
#   http://data.seoul.go.kr/dataList/OA-12252/S/1/datasetView.do

# %%
import pandas as pd

# %%
# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 필요한 패키지와 라이브러리 가져온다.
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# 폰트 지정하기
plt.rcParams['font.family'] = 'gulim'

# %% [markdown]
# # 데이터 확인 및 전처리
#  * 월별, 시간대별, 역별 지하철 승하차정보 데이터이다.

# %%
df = pd.read_csv('C:/workspace/Test_Data/서울시 지하철 호선별 역별 시간대별 승하차 인원 정보.csv', encoding='cp949')

# %%
df.head()
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202108  1호선  동대문           415            11         10380          1815
# 1  202108  1호선  동묘앞            84             3          2861           918
# 2  202108  1호선  서울역           483            11          7963          5533
# 3  202108  1호선   시청             6             0          1597          4399
# 4  202108  1호선  신설동           247             6          6828          2721
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 하차인원  00시-01시 승차인원  \
# 0          7880          5352         12037  ...          5983             7
# 1          3286          4614          5128  ...          1759             4
# 2         10871         31479         31643  ...          4968            21
# 3          2727         17957          5971  ...           822             3
# 4          7333          9771         14821  ...          3747            15
#
# ...

# %%
df.tail()
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  \
# 46547  201501  중앙선  운길산             0             0           177
# 46548  201501  중앙선   원덕             1             0           292
# 46549  201501  중앙선   중랑            14             1          4929
# 46550  201501  중앙선   팔당             0             0           161
# 46551  201501  중앙선   회기           436             3         10929
#
#        05시-06시 하차인원  06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  \
# 46547            56           642           403          1292  ...
# 46548             4           415            46           537  ...
# 46549           424          8539          2084         22160  ...
# 46550            50           368           149          1227  ...
# 46551          3067         23317         10430         65043  ...
#
#        23시-24시 하차인원  00시-01시 승차인원  00시-01시 하차인원  01시-02시 승차인원  01시-02시 하차인원  \
# 46547           633             3           222             0             0
# ...

# %% [markdown]
# ## 데이터 크기

# %%
df.shape
# Out:
# (46552, 52)

# %% [markdown]
# ## 결측치 확인

# %%
df.isnull().sum()
# Out:
# 사용월             0
# 호선명             0
# 지하철역            0
# 04시-05시 승차인원    0
# 04시-05시 하차인원    0
# 05시-06시 승차인원    0
# 05시-06시 하차인원    0
# 06시-07시 승차인원    0
# 06시-07시 하차인원    0
# 07시-08시 승차인원    0
# 07시-08시 하차인원    0
# 08시-09시 승차인원    0
# 08시-09시 하차인원    0
# 09시-10시 승차인원    0
# 09시-10시 하차인원    0
# 10시-11시 승차인원    0
# 10시-11시 하차인원    0
# 11시-12시 승차인원    0
# 11시-12시 하차인원    0
# 12시-13시 승차인원    0
# 12시-13시 하차인원    0
# 13시-14시 승차인원    0
# 13시-14시 하차인원    0
# 14시-15시 승차인원    0
# 14시-15시 하차인원    0
# 15시-16시 승차인원    0
# 15시-16시 하차인원    0
# 16시-17시 승차인원    0
# 16시-17시 하차인원    0
# 17시-18시 승차인원    0
# 17시-18시 하차인원    0
# 18시-19시 승차인원    0
# 18시-19시 하차인원    0
# 19시-20시 승차인원    0
# 19시-20시 하차인원    0
# 20시-21시 승차인원    0
# 20시-21시 하차인원    0
# 21시-22시 승차인원    0
# 21시-22시 하차인원    0
# 22시-23시 승차인원    0
# 22시-23시 하차인원    0
# 23시-24시 승차인원    0
# 23시-24시 하차인원    0
# 00시-01시 승차인원    0
# 00시-01시 하차인원    0
# 01시-02시 승차인원    0
# 01시-02시 하차인원    0
# 02시-03시 승차인원    0
# 02시-03시 하차인원    0
# 03시-04시 승차인원    0
# ...

# %% [markdown]
# ## 컬럼별 데이터 확인

# %%
# 사용월
df['사용월'].unique ()
# Out:
# array([202108, 202107, 202106, 202105, 202104, 202103, 202102, 202101,
#        202012, 202011, 202010, 202009, 202008, 202007, 202006, 202005,
#        202004, 202003, 202002, 202001, 201912, 201911, 201910, 201909,
#        201908, 201907, 201906, 201905, 201904, 201903, 201902, 201901,
#        201812, 201811, 201810, 201809, 201808, 201807, 201806, 201805,
#        201804, 201803, 201802, 201801, 201712, 201711, 201710, 201709,
#        201708, 201707, 201706, 201705, 201704, 201703, 201702, 201701,
#        201612, 201611, 201610, 201609, 201608, 201607, 201606, 201605,
#        201604, 201603, 201602, 201601, 201512, 201511, 201510, 201509,
#        201508, 201507, 201506, 201505, 201504, 201503, 201502, 201501],
#       dtype=int64)

# %%
# 호선명
df['호선명'].unique()
# Out:
# array(['1호선', '2호선', '3호선', '4호선', '5호선', '6호선', '7호선', '8호선', '9호선',
#        '9호선2~3단계', '경강선', '경부선', '경원선', '경의선', '경인선', '경춘선', '공항철도 1호선',
#        '과천선', '분당선', '수인선', '안산선', '우이신설선', '일산선', '장항선', '중앙선', '9호선2단계'],
#       dtype=object)

# %% [markdown]
# ## 데이터 타입 확인 및 변경

# %%
df.dtypes
# Out:
# 사용월              int64
# 호선명             object
# 지하철역            object
# 04시-05시 승차인원     int64
# 04시-05시 하차인원     int64
# 05시-06시 승차인원     int64
# 05시-06시 하차인원     int64
# 06시-07시 승차인원     int64
# 06시-07시 하차인원     int64
# 07시-08시 승차인원     int64
# 07시-08시 하차인원     int64
# 08시-09시 승차인원     int64
# 08시-09시 하차인원     int64
# 09시-10시 승차인원     int64
# 09시-10시 하차인원     int64
# 10시-11시 승차인원     int64
# 10시-11시 하차인원     int64
# 11시-12시 승차인원     int64
# 11시-12시 하차인원     int64
# 12시-13시 승차인원     int64
# 12시-13시 하차인원     int64
# 13시-14시 승차인원     int64
# 13시-14시 하차인원     int64
# 14시-15시 승차인원     int64
# 14시-15시 하차인원     int64
# 15시-16시 승차인원     int64
# 15시-16시 하차인원     int64
# 16시-17시 승차인원     int64
# 16시-17시 하차인원     int64
# 17시-18시 승차인원     int64
# 17시-18시 하차인원     int64
# 18시-19시 승차인원     int64
# 18시-19시 하차인원     int64
# 19시-20시 승차인원     int64
# 19시-20시 하차인원     int64
# 20시-21시 승차인원     int64
# 20시-21시 하차인원     int64
# 21시-22시 승차인원     int64
# 21시-22시 하차인원     int64
# 22시-23시 승차인원     int64
# ...

# %%
df['사용월'] = df['사용월'].astype('str')
df.dtypes
# Out:
# 사용월             object
# 호선명             object
# 지하철역            object
# 04시-05시 승차인원     int64
# 04시-05시 하차인원     int64
# 05시-06시 승차인원     int64
# 05시-06시 하차인원     int64
# 06시-07시 승차인원     int64
# 06시-07시 하차인원     int64
# 07시-08시 승차인원     int64
# 07시-08시 하차인원     int64
# 08시-09시 승차인원     int64
# 08시-09시 하차인원     int64
# 09시-10시 승차인원     int64
# 09시-10시 하차인원     int64
# 10시-11시 승차인원     int64
# 10시-11시 하차인원     int64
# 11시-12시 승차인원     int64
# 11시-12시 하차인원     int64
# 12시-13시 승차인원     int64
# 12시-13시 하차인원     int64
# 13시-14시 승차인원     int64
# 13시-14시 하차인원     int64
# 14시-15시 승차인원     int64
# 14시-15시 하차인원     int64
# 15시-16시 승차인원     int64
# 15시-16시 하차인원     int64
# 16시-17시 승차인원     int64
# 16시-17시 하차인원     int64
# 17시-18시 승차인원     int64
# 17시-18시 하차인원     int64
# 18시-19시 승차인원     int64
# 18시-19시 하차인원     int64
# 19시-20시 승차인원     int64
# 19시-20시 하차인원     int64
# 20시-21시 승차인원     int64
# 20시-21시 하차인원     int64
# 21시-22시 승차인원     int64
# 21시-22시 하차인원     int64
# 22시-23시 승차인원     int64
# ...

# %% [markdown]
# ## 불필요한 컬럼 삭제

# %%
df.drop(columns =['작업일자'], inplace = True)

# %%
df.head(2)
# Out:
#       사용월  호선명 지하철역  04시-05시 승차인원  04시-05시 하차인원  05시-06시 승차인원  05시-06시 하차인원  \
# 0  202108  1호선  동대문           415            11         10380          1815
# 1  202108  1호선  동묘앞            84             3          2861           918
#
#    06시-07시 승차인원  06시-07시 하차인원  07시-08시 승차인원  ...  23시-24시 승차인원  23시-24시 하차인원  \
# 0          7880          5352         12037  ...          1633          5983
# 1          3286          4614          5128  ...           577          1759
#
#    00시-01시 승차인원  00시-01시 하차인원  01시-02시 승차인원  01시-02시 하차인원  02시-03시 승차인원  \
# 0             7          1043             2             2             0
# 1             4           827             0             0             0
#
#    02시-03시 하차인원  03시-04시 승차인원  03시-04시 하차인원
# 0             2             0             0
# 1             0             0             0
#
# [2 rows x 51 columns]

# %% [markdown]
# ## 승차/하차 테이블 분리

# %% [markdown]
# ### 승차 테이블 만들기

# %%
# 공통 컬럼
df1 = df.iloc[:, :3]
# 승차 컬럼만 가져오기
df2 = df.iloc[:, 3::2]

# %%
# 공통컬럼과 승차컬럼 연결하기
df_in = pd.concat([df1 , df2], axis =1)
df_in
# Out:
#           사용월  호선명 지하철역  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  \
# 0      202108  1호선  동대문           415         10380          7880
# 1      202108  1호선  동묘앞            84          2861          3286
# 2      202108  1호선  서울역           483          7963         10871
# 3      202108  1호선   시청             6          1597          2727
# 4      202108  1호선  신설동           247          6828          7333
# ...       ...  ...  ...           ...           ...           ...
# 46547  201501  중앙선  운길산             0           177           642
# 46548  201501  중앙선   원덕             1           292           415
# 46549  201501  중앙선   중랑            14          4929          8539
# 46550  201501  중앙선   팔당             0           161           368
# 46551  201501  중앙선   회기           436         10929         23317
#
#        07시-08시 승차인원  08시-09시 승차인원  09시-10시 승차인원  10시-11시 승차인원  ...  \
# 0             12037         16637         15671         13922  ...
# ...

# %% [markdown]
# ## 하차 테이블 만들기

# %%
# 공통 컬럼

# 하차 컬럼만 가져오기
df3 = df.iloc[:,4::2]

# %%
# 공통컬럼과 하차컬럼 연결하기
df_out = pd.concat([df1,df3], axis =1)
df_out
# Out:
#           사용월  호선명 지하철역  04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  \
# 0      202108  1호선  동대문            11          1815          5352
# 1      202108  1호선  동묘앞             3           918          4614
# 2      202108  1호선  서울역            11          5533         31479
# 3      202108  1호선   시청             0          4399         17957
# 4      202108  1호선  신설동             6          2721          9771
# ...       ...  ...  ...           ...           ...           ...
# 46547  201501  중앙선  운길산             0            56           403
# 46548  201501  중앙선   원덕             0             4            46
# 46549  201501  중앙선   중랑             1           424          2084
# 46550  201501  중앙선   팔당             0            50           149
# 46551  201501  중앙선   회기             3          3067         10430
#
#        07시-08시 하차인원  08시-09시 하차인원  09시-10시 하차인원  10시-11시 하차인원  ...  \
# 0              9885         19783         19192         17298  ...
# ...

# %% [markdown]
# # 출퇴근시간 역별 승하차인원 분석

# %% [markdown]
# * 최근 월을 기준으로 한 승하차 데이터프레임 생성

# %%
df_in_2108 = df_in[df_in['사용월'] == '202108']
df_out_2108 = df_out[df_out['사용월'] == '202108']

# %%
df_out_2108.tail()
# Out:
#         사용월  호선명 지하철역  04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  \
# 602  202108  중앙선   원덕             0             1           261           477
# 603  202108  중앙선   중랑             4           572          2261          2544
# 604  202108  중앙선   지평             0             0             0           298
# 605  202108  중앙선   팔당             0           117           783          1603
# 606  202108  중앙선   회기            12          3419         10520         24212
#
#      08시-09시 하차인원  09시-10시 하차인원  10시-11시 하차인원  ...  18시-19시 하차인원  \
# 602           613           522           665  ...           701
# 603          5744          4790          4282  ...         20675
# 604            58             3           422  ...           137
# 605          2790          3084          3007  ...          1828
# 606         40739         26807         23533  ...         62992
#
#      19시-20시 하차인원  20시-21시 하차인원  21시-22시 하차인원  22시-23시 하차인원  23시-24시 하차인원  \
# ...

# %% [markdown]
# * 출근시간에 가장 많은 사람이 승차하는 역은 어디일까? (08시-09시)

# %%
df_in_2108.nlargest(10, '08시-09시 승차인원')[['지하철역', '08시-09시 승차인원']]
# Out:
#             지하철역  08시-09시 승차인원
# 37            신림        267128
# 14       구로디지털단지        153411
# 28   서울대입구(관악구청)        150090
# 83           연신내        132615
# 133          까치산        130443
# 52      잠실(송파구청)        128005
# 175           화곡        121310
# 112           쌍문        112812
# 36           신도림        111452
# 35           신대방        110766

# %% [markdown]
# * 출근시간에 가장 많은 사람이 하차하는 역은 어디일까?(09시-10시)

# %%
df_out_2108.nlargest(10, '09시-10시 하차인원')[['지하철역','09시-10시 하차인원']]
# Out:
#            지하철역  09시-10시 하차인원
# 10           강남        274355
# 43           역삼        226437
# 215     가산디지털단지        188412
# 30           선릉        178766
# 26     삼성(무역센터)        172539
# 80          압구정        139283
# 31           성수        124935
# 78           신사        122905
# 13   교대(법원.검찰청)        121163
# 14      구로디지털단지        121092

# %% [markdown]
# * 퇴근시간에 가장 많은 사람이 승차하는 역은 어디일까?(18시-19시)

# %%
df_in_2108.nlargest(10, '18시-19시 승차인원')[['지하철역','18시-19시 승차인원']]
# Out:
#             지하철역  18시-19시 승차인원
# 10            강남        302398
# 215      가산디지털단지        283125
# 30            선릉        245318
# 43            역삼        239209
# 26      삼성(무역센터)        230299
# 50         을지로입구        207093
# 31            성수        202624
# 14       구로디지털단지        192537
# 82      양재(서초구청)        174296
# 128  광화문(세종문화회관)        173772

# %% [markdown]
# * 퇴근시간에 가장 많은 사람이 하차하는 역은 어디일까?(19시-20시)

# %%
df_out_2108.nlargest(10, '19시-20시 하차인원')[['지하철역','19시-20시 하차인원']]
# Out:
#             지하철역  19시-20시 하차인원
# 37            신림        182832
# 28   서울대입구(관악구청)        121426
# 52      잠실(송파구청)        116568
# 14       구로디지털단지        107520
# 83           연신내        103283
# 36           신도림         97759
# 109     수유(강북구청)         93666
# 133          까치산         87948
# 112           쌍문         86631
# 438           부천         85018

# %% [markdown]
# # 강남역의 최근 시간대별 승하차정보 분석

# %% [markdown]
# ## 강남역의 최근 승차정보 분석

# %%
# 강남역의 최근 승차 데이터 불러오기 
df_gangnam_in = df_in_2108[df_in_2108['지하철역'] =='강남'].iloc[:, 3:]
df_gangnam_in
# Out:
#     04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  08시-09시 승차인원  \
# 10            64          4993         14177         31783         50239
#
#     09시-10시 승차인원  10시-11시 승차인원  11시-12시 승차인원  12시-13시 승차인원  13시-14시 승차인원  ...  \
# 10         40611         44108         59573         75942         88926  ...
#
#     18시-19시 승차인원  19시-20시 승차인원  20시-21시 승차인원  21시-22시 승차인원  22시-23시 승차인원  \
# 10        302398        178242        138452        157847        105997
#
#     23시-24시 승차인원  00시-01시 승차인원  01시-02시 승차인원  02시-03시 승차인원  03시-04시 승차인원
# 10         12509             5             2             0             0
#
# [1 rows x 24 columns]

# %%
# melt
df_gangnam_in = df_gangnam_in.melt()
df_gangnam_in
# Out:
#         variable   value
# 0   04시-05시 승차인원      64
# 1   05시-06시 승차인원    4993
# 2   06시-07시 승차인원   14177
# 3   07시-08시 승차인원   31783
# 4   08시-09시 승차인원   50239
# 5   09시-10시 승차인원   40611
# 6   10시-11시 승차인원   44108
# 7   11시-12시 승차인원   59573
# 8   12시-13시 승차인원   75942
# 9   13시-14시 승차인원   88926
# 10  14시-15시 승차인원   97964
# 11  15시-16시 승차인원  120268
# 12  16시-17시 승차인원  135621
# 13  17시-18시 승차인원  214990
# 14  18시-19시 승차인원  302398
# 15  19시-20시 승차인원  178242
# 16  20시-21시 승차인원  138452
# 17  21시-22시 승차인원  157847
# 18  22시-23시 승차인원  105997
# 19  23시-24시 승차인원   12509
# 20  00시-01시 승차인원       5
# 21  01시-02시 승차인원       2
# 22  02시-03시 승차인원       0
# 23  03시-04시 승차인원       0

# %%
# 컬럼명 변경
df_gangnam_in.columns = ['시간대','승차건수']
df_gangnam_in.sort_values('승차건수')
# Out:
#              시간대    승차건수
# 23  03시-04시 승차인원       0
# 22  02시-03시 승차인원       0
# 21  01시-02시 승차인원       2
# 20  00시-01시 승차인원       5
# 0   04시-05시 승차인원      64
# 1   05시-06시 승차인원    4993
# 19  23시-24시 승차인원   12509
# 2   06시-07시 승차인원   14177
# 3   07시-08시 승차인원   31783
# 5   09시-10시 승차인원   40611
# 6   10시-11시 승차인원   44108
# 4   08시-09시 승차인원   50239
# 7   11시-12시 승차인원   59573
# 8   12시-13시 승차인원   75942
# 9   13시-14시 승차인원   88926
# 10  14시-15시 승차인원   97964
# 18  22시-23시 승차인원  105997
# 11  15시-16시 승차인원  120268
# 12  16시-17시 승차인원  135621
# 16  20시-21시 승차인원  138452
# 17  21시-22시 승차인원  157847
# 15  19시-20시 승차인원  178242
# 13  17시-18시 승차인원  214990
# 14  18시-19시 승차인원  302398

# %%
# 시간대별 승차인원 시각화하기
plt.figure(figsize =(10,7))
x = df_gangnam_in['시간대']
y = df_gangnam_in['승차건수']
plt.barh(x,y, color = 'pink')
plt.show()

# %% [markdown]
# ## 강남역의 최근 하차 정보 분석

# %%
# 강남역의 최근 하차 데이터 불러오기 
df_gangnam_out = df_out_2108[df_out_2108['지하철역'] == '강남'].iloc[:, 3:]
df_gangnam_out
# Out:
#     04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  08시-09시 하차인원  \
# 10             4         10411         45059        129595        269877
#
#     09시-10시 하차인원  10시-11시 하차인원  11시-12시 하차인원  12시-13시 하차인원  13시-14시 하차인원  ...  \
# 10        274355        129744         99120         96644        115153  ...
#
#     18시-19시 하차인원  19시-20시 하차인원  20시-21시 하차인원  21시-22시 하차인원  22시-23시 하차인원  \
# 10        125891         68747         34635         27783         21970
#
#     23시-24시 하차인원  00시-01시 하차인원  01시-02시 하차인원  02시-03시 하차인원  03시-04시 하차인원
# 10          8377            15             1             0             0
#
# [1 rows x 24 columns]

# %%
# melt
df_gangnam_out = df_gangnam_out.melt()
df_gangnam_out
# Out:
#         variable   value
# 0   04시-05시 하차인원       4
# 1   05시-06시 하차인원   10411
# 2   06시-07시 하차인원   45059
# 3   07시-08시 하차인원  129595
# 4   08시-09시 하차인원  269877
# 5   09시-10시 하차인원  274355
# 6   10시-11시 하차인원  129744
# 7   11시-12시 하차인원   99120
# 8   12시-13시 하차인원   96644
# 9   13시-14시 하차인원  115153
# 10  14시-15시 하차인원   94620
# 11  15시-16시 하차인원   86770
# 12  16시-17시 하차인원   83690
# 13  17시-18시 하차인원   96689
# 14  18시-19시 하차인원  125891
# 15  19시-20시 하차인원   68747
# 16  20시-21시 하차인원   34635
# 17  21시-22시 하차인원   27783
# 18  22시-23시 하차인원   21970
# 19  23시-24시 하차인원    8377
# 20  00시-01시 하차인원      15
# 21  01시-02시 하차인원       1
# 22  02시-03시 하차인원       0
# 23  03시-04시 하차인원       0

# %%
# 컬럼명 변경
df_gangnam_out.columns= ['시간대별 하차인원','하차건수']
df_gangnam_out.sort_values('하차건수')
# Out:
#        시간대별 하차인원    하차건수
# 23  03시-04시 하차인원       0
# 22  02시-03시 하차인원       0
# 21  01시-02시 하차인원       1
# 0   04시-05시 하차인원       4
# 20  00시-01시 하차인원      15
# 19  23시-24시 하차인원    8377
# 1   05시-06시 하차인원   10411
# 18  22시-23시 하차인원   21970
# 17  21시-22시 하차인원   27783
# 16  20시-21시 하차인원   34635
# 2   06시-07시 하차인원   45059
# 15  19시-20시 하차인원   68747
# 12  16시-17시 하차인원   83690
# 11  15시-16시 하차인원   86770
# 10  14시-15시 하차인원   94620
# 8   12시-13시 하차인원   96644
# 13  17시-18시 하차인원   96689
# 7   11시-12시 하차인원   99120
# 9   13시-14시 하차인원  115153
# 14  18시-19시 하차인원  125891
# 3   07시-08시 하차인원  129595
# 6   10시-11시 하차인원  129744
# 4   08시-09시 하차인원  269877
# 5   09시-10시 하차인원  274355

# %%
# 시간대별 승차인원 시각화하기
plt.figure(figsize =(10,7))
x = df_gangnam_out['시간대별 하차인원']
y = df_gangnam_out['하차건수']
plt.barh(x,y, color = 'pink')
plt.show()

# %% [markdown]
# # 지하철 시간대별, 역별 이용현황 분석

# %% [markdown]
# ## 시간대별 승차 현황

# %% [markdown]
# ### 승차정보 집계 데이터 만들기

# %%
# df_in_2108카피하여 사용하기
df_in_2108_agg = df_in_2108.copy()

# %%
df_in_2108_agg
# Out:
#         사용월  호선명 지하철역  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  \
# 0    202108  1호선  동대문           415         10380          7880         12037
# 1    202108  1호선  동묘앞            84          2861          3286          5128
# 2    202108  1호선  서울역           483          7963         10871         31643
# 3    202108  1호선   시청             6          1597          2727          5971
# 4    202108  1호선  신설동           247          6828          7333         14821
# ..      ...  ...  ...           ...           ...           ...           ...
# 602  202108  중앙선   원덕            72           277           689           643
# 603  202108  중앙선   중랑           200          5961          8782         19739
# 604  202108  중앙선   지평             0             1             2           347
# 605  202108  중앙선   팔당             1           212           788          1261
# 606  202108  중앙선   회기           719         11133         18619         47471
#
# ...

# %%
# 인덱스 변경('지하철역')
# df_in_2108_agg.index = df_in_2108_agg['지하철역']
df_in_2108_agg.set_index('지하철역', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 2
#       1 # 인덱스 변경('지하철역')
# ----> 2 df_in_2108_agg.set_index('지하철역', inplace = True)
#
# File C:\Python39\lib\site-packages\pandas\core\frame.py:5870, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5867                 missing.append(col)
#    5869 if missing:
# -> 5870     raise KeyError(f"None of {missing} are in the columns")
#    5872 if inplace:
#    5873     frame = self
#
# KeyError: "None of ['지하철역'] are in the columns"

# %%
df_in_2108_agg
# Out:
#          사용월  호선명  04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  \
# 지하철역
# 동대문   202108  1호선           415         10380          7880         12037
# 동묘앞   202108  1호선            84          2861          3286          5128
# 서울역   202108  1호선           483          7963         10871         31643
# 시청    202108  1호선             6          1597          2727          5971
# 신설동   202108  1호선           247          6828          7333         14821
# ...      ...  ...           ...           ...           ...           ...
# 원덕    202108  중앙선            72           277           689           643
# 중랑    202108  중앙선           200          5961          8782         19739
# 지평    202108  중앙선             0             1             2           347
# 팔당    202108  중앙선             1           212           788          1261
# 회기    202108  중앙선           719         11133         18619         47471
#
#       08시-09시 승차인원  09시-10시 승차인원  10시-11시 승차인원  11시-12시 승차인원  ...  \
# ...

# %%
# 컬럼 삭제('사용월','호선명','지하철역')
# df_in_2108_agg.drop(['사용월','호선명'], axis = 1)   # default => axis = 0
df_in_2108_agg.drop(columns =['사용월','호선명'], inplace = True)

# %%
df_in_2108_agg
# Out:
#       04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  08시-09시 승차인원  \
# 지하철역
# 동대문            415         10380          7880         12037         16637
# 동묘앞             84          2861          3286          5128          8066
# 서울역            483          7963         10871         31643         49003
# 시청               6          1597          2727          5971          6884
# 신설동            247          6828          7333         14821         20523
# ...            ...           ...           ...           ...           ...
# 원덕              72           277           689           643           883
# 중랑             200          5961          8782         19739         18610
# 지평               0             1             2           347           218
# 팔당               1           212           788          1261          1267
# 회기             719         11133         18619         47471         59922
#
# ...

# %%
# 행,열 합계
df_in_2108_agg['sum'] = df_in_2108_agg.apply('sum',axis = 1)  # df_in_2108_agg['sum'].agg('sum')
df_in_2108_agg
# Out:
#       04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  08시-09시 승차인원  \
# 지하철역
# 동대문            415         10380          7880         12037         16637
# 동묘앞             84          2861          3286          5128          8066
# 서울역            483          7963         10871         31643         49003
# 시청               6          1597          2727          5971          6884
# 신설동            247          6828          7333         14821         20523
# ...            ...           ...           ...           ...           ...
# 원덕              72           277           689           643           883
# 중랑             200          5961          8782         19739         18610
# 지평               0             1             2           347           218
# 팔당               1           212           788          1261          1267
# 회기             719         11133         18619         47471         59922
#
# ...

# %%
df_in_2108_agg.loc['sum'] = df_in_2108_agg.apply('sum',axis = 0)
df_in_2108_agg
# Out:
#       04시-05시 승차인원  05시-06시 승차인원  06시-07시 승차인원  07시-08시 승차인원  08시-09시 승차인원  \
# 지하철역
# 동대문            415         10380          7880         12037         16637
# 동묘앞             84          2861          3286          5128          8066
# 서울역            483          7963         10871         31643         49003
# 시청               6          1597          2727          5971          6884
# 신설동            247          6828          7333         14821         20523
# ...            ...           ...           ...           ...           ...
# 중랑             200          5961          8782         19739         18610
# 지평               0             1             2           347           218
# 팔당               1           212           788          1261          1267
# 회기             719         11133         18619         47471         59922
# sum         125592       2679895       5392644      13007398      14639529
#
# ...

# %% [markdown]
# ### 시간대별 승차건수

# %%
s_in = df_in_2108_agg.loc['sum'][:-1].sort_values()

# %%
s_in = s_in.sort_index()
s_in
# Out:
# 00시-01시 승차인원        6086
# 01시-02시 승차인원          26
# 02시-03시 승차인원           3
# 03시-04시 승차인원           1
# 04시-05시 승차인원      125592
# 05시-06시 승차인원     2679895
# 06시-07시 승차인원     5392644
# 07시-08시 승차인원    13007398
# 08시-09시 승차인원    14639529
# 09시-10시 승차인원     8962001
# 10시-11시 승차인원     6688112
# 11시-12시 승차인원     6762631
# 12시-13시 승차인원     7277223
# 13시-14시 승차인원     7301932
# 14시-15시 승차인원     7314360
# 15시-16시 승차인원     8054562
# 16시-17시 승차인원     9285727
# 17시-18시 승차인원    12846619
# 18시-19시 승차인원    17191309
# 19시-20시 승차인원     8671470
# 20시-21시 승차인원     6611588
# 21시-22시 승차인원     6032973
# 22시-23시 승차인원     3852573
# 23시-24시 승차인원      744365
# Name: sum, dtype: int64

# %%
x = s_in.index
y = s_in.values
plt.bar(x,y)
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ### 지하철역별 승차건수

# %%
# 데이터 프레임으로 
df_in_2108_agg['sum'][:-1].sort_values(ascending = False).to_frame()
# Out:
#               sum
# 지하철역
# 강남        1874711
# 잠실(송파구청)  1539356
# 신림        1503604
# 구로디지털단지   1331304
# 홍대입구      1247932
# ...           ...
# 창동              6
# 계양              5
# 지축              4
# 검암              4
# 신내              3
#
# [607 rows x 1 columns]

# %% [markdown]
# ## 시간대별 하차 현황

# %% [markdown]
# ### 하차정보 집계 테이블 만들기

# %%
# df_out_202108카피하여 사용하기
df_out_2108_agg = df_out_2108.copy()
df_out_2108_agg
# Out:
#         사용월  호선명 지하철역  04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  \
# 0    202108  1호선  동대문            11          1815          5352          9885
# 1    202108  1호선  동묘앞             3           918          4614          8004
# 2    202108  1호선  서울역            11          5533         31479         73669
# 3    202108  1호선   시청             0          4399         17957         53669
# 4    202108  1호선  신설동             6          2721          9771         21765
# ..      ...  ...  ...           ...           ...           ...           ...
# 602  202108  중앙선   원덕             0             1           261           477
# 603  202108  중앙선   중랑             4           572          2261          2544
# 604  202108  중앙선   지평             0             0             0           298
# 605  202108  중앙선   팔당             0           117           783          1603
# 606  202108  중앙선   회기            12          3419         10520         24212
#
# ...

# %%
# 인덱스 변경('지하철역')
df_out_2108_agg.set_index('지하철역', inplace = True)
df_out_2108_agg
# Out:
#          사용월  호선명  04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  \
# 지하철역
# 동대문   202108  1호선            11          1815          5352          9885
# 동묘앞   202108  1호선             3           918          4614          8004
# 서울역   202108  1호선            11          5533         31479         73669
# 시청    202108  1호선             0          4399         17957         53669
# 신설동   202108  1호선             6          2721          9771         21765
# ...      ...  ...           ...           ...           ...           ...
# 원덕    202108  중앙선             0             1           261           477
# 중랑    202108  중앙선             4           572          2261          2544
# 지평    202108  중앙선             0             0             0           298
# 팔당    202108  중앙선             0           117           783          1603
# 회기    202108  중앙선            12          3419         10520         24212
#
#       08시-09시 하차인원  09시-10시 하차인원  10시-11시 하차인원  11시-12시 하차인원  ...  \
# ...

# %%
# 컬럼 삭제('사용월','호선명','지하철역')
df_out_2108_agg = df_out_2108_agg.drop(['사용월','호선명'] , axis = 1 )

# %%
df_out_2108_agg
# Out:
#       04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  08시-09시 하차인원  \
# 지하철역
# 동대문             11          1815          5352          9885         19783
# 동묘앞              3           918          4614          8004         18779
# 서울역             11          5533         31479         73669        149249
# 시청               0          4399         17957         53669        141150
# 신설동              6          2721          9771         21765         52910
# ...            ...           ...           ...           ...           ...
# 원덕               0             1           261           477           613
# 중랑               4           572          2261          2544          5744
# 지평               0             0             0           298            58
# 팔당               0           117           783          1603          2790
# 회기              12          3419         10520         24212         40739
#
# ...

# %%
# 행,열 합계
df_out_2108_agg['sum'] = df_out_2108_agg.apply('sum', axis =1)

# %%
df_out_2108_agg
# Out:
#       04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  08시-09시 하차인원  \
# 지하철역
# 동대문             11          1815          5352          9885         19783
# 동묘앞              3           918          4614          8004         18779
# 서울역             11          5533         31479         73669        149249
# 시청               0          4399         17957         53669        141150
# 신설동              6          2721          9771         21765         52910
# ...            ...           ...           ...           ...           ...
# 원덕               0             1           261           477           613
# 중랑               4           572          2261          2544          5744
# 지평               0             0             0           298            58
# 팔당               0           117           783          1603          2790
# 회기              12          3419         10520         24212         40739
#
# ...

# %%
df_out_2108_agg.loc['sum'] = df_out_2108_agg.apply('sum', axis = 0)

# %%
df_out_2108_agg
# Out:
#       04시-05시 하차인원  05시-06시 하차인원  06시-07시 하차인원  07시-08시 하차인원  08시-09시 하차인원  \
# 지하철역
# 동대문             11          1815          5352          9885         19783
# 동묘앞              3           918          4614          8004         18779
# 서울역             11          5533         31479         73669        149249
# 시청               0          4399         17957         53669        141150
# 신설동              6          2721          9771         21765         52910
# ...            ...           ...           ...           ...           ...
# 중랑               4           572          2261          2544          5744
# 지평               0             0             0           298            58
# 팔당               0           117           783          1603          2790
# 회기              12          3419         10520         24212         40739
# sum           1644        706189       3603606       8042590      17604264
#
# ...

# %% [markdown]
# ### 시간대별 하차 건수

# %%
df_out_2108_agg.loc['sum'][:-1].sort_values().to_frame()
# Out:
#                    sum
# 03시-04시 하차인원         1
# 02시-03시 하차인원        12
# 01시-02시 하차인원        66
# 04시-05시 하차인원      1644
# 00시-01시 하차인원    214094
# 05시-06시 하차인원    706189
# 23시-24시 하차인원   2216218
# 06시-07시 하차인원   3603606
# 22시-23시 하차인원   5217987
# 21시-22시 하차인원   6338999
# 11시-12시 하차인원   6666215
# 12시-13시 하차인원   7062738
# 20시-21시 하차인원   7093483
# 10시-11시 하차인원   7146549
# 14시-15시 하차인원   7174578
# 13시-14시 하차인원   7449305
# 15시-16시 하차인원   7581218
# 07시-08시 하차인원   8042590
# 16시-17시 하차인원   8380236
# 17시-18시 하차인원  10646691
# 09시-10시 하차인원  11402630
# 19시-20시 하차인원  12354319
# 18시-19시 하차인원  16007443
# 08시-09시 하차인원  17604264

# %% [markdown]
# ### 지하철역별 하차건수

# %%
s_out =df_out_2108_agg['sum'][:-1].sort_values()
s_out
# Out:
# 지하철역
# 충무로               0
# 창동                0
# 지축                0
# 검암                0
# 계양                0
#              ...
# 홍대입구        1273453
# 구로디지털단지     1339493
# 신림          1467939
# 잠실(송파구청)    1514327
# 강남          1819150
# Name: sum, Length: 607, dtype: int64

# %%
x = s_out.index
y = s_out.values
plt.barh(x, y)
plt.show()
